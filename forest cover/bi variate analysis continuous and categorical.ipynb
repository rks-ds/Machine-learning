# %%
# bi variate analysis cont categorical
import pandas as pd
n_train=pd.read_csv("ntrain.csv")
n_train.shape
# Out:
# (15120, 3)

# %%
train=pd.read_csv("train_new.csv")
train.shape
# Out:
# (15120, 54)

# %%
col_names=list(train.ix[:,1:11].columns)

# %%
col_names
# Out:
# ['Elevation',
#  'Aspect',
#  'Slope',
#  'Horizontal_Distance_To_Hydrology',
#  'Vertical_Distance_To_Hydrology',
#  'Horizontal_Distance_To_Roadways',
#  'Hillshade_9am',
#  'Hillshade_Noon',
#  'Hillshade_3pm',
#  'Horizontal_Distance_To_Fire_Points']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for name in col_names:
     sns.boxplot(x="Cover_Type",y=name,data=train)
     plt.show()
    
# lot of outliers and i guess transformation will reduce them
#elevation looks like a good distinctive parameter
#Horizontal_distance_to_hydrology lot of zeros

# %%
for name in col_names:
     sns.boxplot(x=n_train['Wilderness_Area'],y=train[name])
     plt.show()

# by far it looks like elevation is best criteria

# %%
for name in col_names:
     sns.boxplot(x=n_train['Soil_Type'],y=train[name])
     plt.show()
#elevation shows lot of distinction
